# %% [markdown]
# ---
# **Dylan Govender - 221040222 - Assignment III - COMP703**
# ---

# %% [markdown]
# ## **1. Importing the Data**

# %%
# !wget "http://www.manythings.org/anki/fra-eng.zip"
# !unzip fra-eng.zip
# Out:
# --2024-05-24 18:08:22--  http://www.manythings.org/anki/fra-eng.zip
# Resolving www.manythings.org (www.manythings.org)... 173.254.30.110
# Connecting to www.manythings.org (www.manythings.org)|173.254.30.110|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7943074 (7.6M) [application/zip]
# Saving to: ‘fra-eng.zip’
#
# fra-eng.zip         100%[===================>]   7.57M  3.77MB/s    in 2.0s
#
# 2024-05-24 18:08:25 (3.77 MB/s) - ‘fra-eng.zip’ saved [7943074/7943074]
#
# Archive:  fra-eng.zip
#   inflating: _about.txt
#   inflating: fra.txt

# %% [markdown]
# ## **2. Data Preprocessing**

# %%
import numpy as np

# Configuration
MAX_SAMPLES = 10000  # Number of samples to train on.

input_texts = [] # saves first language sentences (input)
target_texts = [] # saves second language sentences (output)
input_characters = set() # saves unique first language words
target_characters = set() # saves unique second language words

with open("//content//fra.txt", "r", encoding="utf-8") as file:
    lines = file.read().split("\n")
    for line in lines[:min(MAX_SAMPLES, len(lines)-1)]:
        input_text, target_text, _ = line.split("\t")

        # "\t" is start sequence character for target sentence
        # "\n" is the end sequence character for target sentence
        target_text = "\t" + target_text + "\n"
        input_texts.append(input_text)
        target_texts.append(target_text)

        for char in input_text:
            if char not in input_characters:
                input_characters.add(char)

        for char in target_text:
            if char not in target_characters:
                target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(text) for text in input_texts])
max_decoder_seq_length = max([len(text) for text in target_texts])

print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)

input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype="float32",
)

decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype="float32",
)

decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype="float32",
)

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[" "]] = 1.0

    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0

        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0

    decoder_input_data[i, t + 1 :, target_token_index[" "]] = 1.0
    decoder_target_data[i, t:, target_token_index[" "]] = 1.0
# Out:
# Number of samples: 10000
# Number of unique input tokens: 70
# Number of unique output tokens: 91
# Max sequence length for inputs: 14
# Max sequence length for outputs: 59

# %% [markdown]
# ## **3. Building the Model: Bi-GRU Encoder & GRU Decoder**

# %%
import tensorflow, keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Reshape, Input, Bidirectional, GRU, Embedding, Dense, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Define an input sequence and process it.
LATENT_DIM = 256

# Encoder
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = Bidirectional(GRU(LATENT_DIM, return_state=True))
encoder_outputs, forward_h, backward_h = encoder(encoder_inputs)
state_h = Concatenate()([forward_h, backward_h])

# Decoder
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_gru = GRU(2*LATENT_DIM, return_sequences=True, return_state=True)
decoder_outputs, _ = decoder_gru(decoder_inputs, initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs,  name="BiGRU_GRU_model")
model.summary()
# Out:
# Model: "BiGRU_GRU_model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, 70)]           0         []
#
#  bidirectional (Bidirection  [(None, 512),                503808    ['input_1[0][0]']
#  al)                          (None, 256),
#                               (None, 256)]
#
#  input_2 (InputLayer)        [(None, None, 91)]           0         []
#
#  concatenate (Concatenate)   (None, 512)                  0         ['bidirectional[0][1]',
#                                                                      'bidirectional[0][2]']
#
#  gru_1 (GRU)                 [(None, None, 512),          929280    ['input_2[0][0]',
#                               (None, 512)]                           'concatenate[0][0]']
#
#  dense (Dense)               (None, None, 91)             46683     ['gru_1[0][0]']
#
# ==================================================================================================
# Total params: 1479771 (5.64 MB)
# Trainable params: 1479771 (5.64 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## **4. Training the Model: Bi-GRU Encoder & GRU Decoder**

# %%
BATCH_SIZE = 64  # batch size for training
EPOCHS = 100  # number of epochs to train for

model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)

model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_split=0.2,
)

# save model
model.save("BiGRU_GRU_model.keras")
# Out:
# Epoch 1/100
# 125/125 [==============================] - 9s 39ms/step - loss: 1.2135 - accuracy: 0.7342 - val_loss: 1.0561 - val_accuracy: 0.7168
# Epoch 2/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.8430 - accuracy: 0.7709 - val_loss: 0.8514 - val_accuracy: 0.7629
# Epoch 3/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.6912 - accuracy: 0.8015 - val_loss: 0.7239 - val_accuracy: 0.7908
# Epoch 4/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.6285 - accuracy: 0.8168 - val_loss: 0.6841 - val_accuracy: 0.7985
# Epoch 5/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.5950 - accuracy: 0.8256 - val_loss: 0.6551 - val_accuracy: 0.8071
# Epoch 6/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.5709 - accuracy: 0.8321 - val_loss: 0.6343 - val_accuracy: 0.8112
# Epoch 7/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.5516 - accuracy: 0.8371 - val_loss: 0.6167 - val_accuracy: 0.8205
# Epoch 8/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.5354 - accuracy: 0.8414 - val_loss: 0.5986 - val_accuracy: 0.8247
# Epoch 9/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.5211 - accuracy: 0.8455 - val_loss: 0.5825 - val_accuracy: 0.8273
# Epoch 10/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.5068 - accuracy: 0.8502 - val_loss: 0.5709 - val_accuracy: 0.8328
# Epoch 11/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.4941 - accuracy: 0.8536 - val_loss: 0.5598 - val_accuracy: 0.8344
# Epoch 12/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.4818 - accuracy: 0.8569 - val_loss: 0.5482 - val_accuracy: 0.8364
# Epoch 13/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.4701 - accuracy: 0.8608 - val_loss: 0.5442 - val_accuracy: 0.8378
# Epoch 14/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.4595 - accuracy: 0.8637 - val_loss: 0.5306 - val_accuracy: 0.8425
# Epoch 15/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.4485 - accuracy: 0.8668 - val_loss: 0.5212 - val_accuracy: 0.8452
# Epoch 16/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.4383 - accuracy: 0.8699 - val_loss: 0.5121 - val_accuracy: 0.8487
# Epoch 17/100
# 125/125 [==============================] - 3s 24ms/step - loss: 0.4282 - accuracy: 0.8725 - val_loss: 0.5024 - val_accuracy: 0.8522
# Epoch 18/100
# 125/125 [==============================] - 4s 29ms/step - loss: 0.4187 - accuracy: 0.8755 - val_loss: 0.4983 - val_accuracy: 0.8523
# Epoch 19/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.4099 - accuracy: 0.8780 - val_loss: 0.4936 - val_accuracy: 0.8548
# Epoch 20/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.4011 - accuracy: 0.8803 - val_loss: 0.4841 - val_accuracy: 0.8574
# Epoch 21/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.3926 - accuracy: 0.8829 - val_loss: 0.4785 - val_accuracy: 0.8585
# Epoch 22/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.3838 - accuracy: 0.8856 - val_loss: 0.4749 - val_accuracy: 0.8605
# Epoch 23/100
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3763 - accuracy: 0.8878 - val_loss: 0.4621 - val_accuracy: 0.8637
# Epoch 24/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.3682 - accuracy: 0.8903 - val_loss: 0.4608 - val_accuracy: 0.8640
# Epoch 25/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.3597 - accuracy: 0.8925 - val_loss: 0.4580 - val_accuracy: 0.8649
# Epoch 26/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.3521 - accuracy: 0.8947 - val_loss: 0.4539 - val_accuracy: 0.8671
# Epoch 27/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.3448 - accuracy: 0.8970 - val_loss: 0.4452 - val_accuracy: 0.8683
# Epoch 28/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.3367 - accuracy: 0.8992 - val_loss: 0.4403 - val_accuracy: 0.8707
# Epoch 29/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.3294 - accuracy: 0.9016 - val_loss: 0.4346 - val_accuracy: 0.8719
# Epoch 30/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.3219 - accuracy: 0.9036 - val_loss: 0.4337 - val_accuracy: 0.8731
# Epoch 31/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.3146 - accuracy: 0.9058 - val_loss: 0.4334 - val_accuracy: 0.8737
# Epoch 32/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.3077 - accuracy: 0.9077 - val_loss: 0.4273 - val_accuracy: 0.8760
# Epoch 33/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.3006 - accuracy: 0.9097 - val_loss: 0.4247 - val_accuracy: 0.8771
# Epoch 34/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.2935 - accuracy: 0.9119 - val_loss: 0.4268 - val_accuracy: 0.8758
# Epoch 35/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2855 - accuracy: 0.9141 - val_loss: 0.4180 - val_accuracy: 0.8789
# Epoch 36/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2788 - accuracy: 0.9159 - val_loss: 0.4193 - val_accuracy: 0.8788
# Epoch 37/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2720 - accuracy: 0.9182 - val_loss: 0.4161 - val_accuracy: 0.8800
# Epoch 38/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2656 - accuracy: 0.9199 - val_loss: 0.4154 - val_accuracy: 0.8813
# Epoch 39/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.2583 - accuracy: 0.9225 - val_loss: 0.4164 - val_accuracy: 0.8815
# Epoch 40/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.2516 - accuracy: 0.9244 - val_loss: 0.4150 - val_accuracy: 0.8823
# Epoch 41/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2451 - accuracy: 0.9263 - val_loss: 0.4166 - val_accuracy: 0.8828
# Epoch 42/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2387 - accuracy: 0.9279 - val_loss: 0.4197 - val_accuracy: 0.8816
# Epoch 43/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2322 - accuracy: 0.9299 - val_loss: 0.4170 - val_accuracy: 0.8822
# Epoch 44/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2256 - accuracy: 0.9322 - val_loss: 0.4213 - val_accuracy: 0.8822
# Epoch 45/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.2196 - accuracy: 0.9337 - val_loss: 0.4194 - val_accuracy: 0.8836
# Epoch 46/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.2135 - accuracy: 0.9356 - val_loss: 0.4240 - val_accuracy: 0.8827
# Epoch 47/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2072 - accuracy: 0.9374 - val_loss: 0.4211 - val_accuracy: 0.8841
# Epoch 48/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2011 - accuracy: 0.9393 - val_loss: 0.4247 - val_accuracy: 0.8842
# Epoch 49/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1956 - accuracy: 0.9407 - val_loss: 0.4261 - val_accuracy: 0.8843
# Epoch 50/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1897 - accuracy: 0.9425 - val_loss: 0.4311 - val_accuracy: 0.8837
# Epoch 51/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1840 - accuracy: 0.9444 - val_loss: 0.4298 - val_accuracy: 0.8842
# Epoch 52/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1785 - accuracy: 0.9459 - val_loss: 0.4363 - val_accuracy: 0.8843
# Epoch 53/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1731 - accuracy: 0.9475 - val_loss: 0.4395 - val_accuracy: 0.8844
# Epoch 54/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1680 - accuracy: 0.9490 - val_loss: 0.4467 - val_accuracy: 0.8834
# Epoch 55/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1626 - accuracy: 0.9508 - val_loss: 0.4473 - val_accuracy: 0.8845
# Epoch 56/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1577 - accuracy: 0.9522 - val_loss: 0.4533 - val_accuracy: 0.8831
# Epoch 57/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1526 - accuracy: 0.9535 - val_loss: 0.4551 - val_accuracy: 0.8841
# Epoch 58/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1481 - accuracy: 0.9552 - val_loss: 0.4615 - val_accuracy: 0.8833
# Epoch 59/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1435 - accuracy: 0.9567 - val_loss: 0.4684 - val_accuracy: 0.8834
# Epoch 60/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1392 - accuracy: 0.9578 - val_loss: 0.4698 - val_accuracy: 0.8828
# Epoch 61/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1347 - accuracy: 0.9591 - val_loss: 0.4746 - val_accuracy: 0.8834
# Epoch 62/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1305 - accuracy: 0.9604 - val_loss: 0.4809 - val_accuracy: 0.8830
# Epoch 63/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1264 - accuracy: 0.9617 - val_loss: 0.4910 - val_accuracy: 0.8811
# Epoch 64/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1224 - accuracy: 0.9626 - val_loss: 0.4902 - val_accuracy: 0.8824
# Epoch 65/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1190 - accuracy: 0.9638 - val_loss: 0.4944 - val_accuracy: 0.8821
# Epoch 66/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1154 - accuracy: 0.9648 - val_loss: 0.5013 - val_accuracy: 0.8823
# Epoch 67/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1121 - accuracy: 0.9658 - val_loss: 0.5089 - val_accuracy: 0.8816
# Epoch 68/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1087 - accuracy: 0.9668 - val_loss: 0.5109 - val_accuracy: 0.8814
# Epoch 69/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.1052 - accuracy: 0.9680 - val_loss: 0.5207 - val_accuracy: 0.8818
# Epoch 70/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1025 - accuracy: 0.9688 - val_loss: 0.5236 - val_accuracy: 0.8809
# Epoch 71/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0993 - accuracy: 0.9696 - val_loss: 0.5283 - val_accuracy: 0.8817
# Epoch 72/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0967 - accuracy: 0.9705 - val_loss: 0.5340 - val_accuracy: 0.8803
# Epoch 73/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0938 - accuracy: 0.9712 - val_loss: 0.5398 - val_accuracy: 0.8811
# Epoch 74/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.0911 - accuracy: 0.9720 - val_loss: 0.5441 - val_accuracy: 0.8806
# Epoch 75/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.0884 - accuracy: 0.9729 - val_loss: 0.5525 - val_accuracy: 0.8797
# Epoch 76/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0860 - accuracy: 0.9736 - val_loss: 0.5550 - val_accuracy: 0.8800
# Epoch 77/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0839 - accuracy: 0.9742 - val_loss: 0.5602 - val_accuracy: 0.8800
# Epoch 78/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0815 - accuracy: 0.9749 - val_loss: 0.5693 - val_accuracy: 0.8787
# Epoch 79/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0791 - accuracy: 0.9754 - val_loss: 0.5686 - val_accuracy: 0.8800
# Epoch 80/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.0772 - accuracy: 0.9761 - val_loss: 0.5813 - val_accuracy: 0.8785
# Epoch 81/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.0752 - accuracy: 0.9768 - val_loss: 0.5831 - val_accuracy: 0.8784
# Epoch 82/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0731 - accuracy: 0.9773 - val_loss: 0.5852 - val_accuracy: 0.8790
# Epoch 83/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0714 - accuracy: 0.9777 - val_loss: 0.5924 - val_accuracy: 0.8797
# Epoch 84/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.0697 - accuracy: 0.9783 - val_loss: 0.6007 - val_accuracy: 0.8785
# Epoch 85/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.0679 - accuracy: 0.9788 - val_loss: 0.6004 - val_accuracy: 0.8785
# Epoch 86/100
# 125/125 [==============================] - 3s 23ms/step - loss: 0.0661 - accuracy: 0.9792 - val_loss: 0.6074 - val_accuracy: 0.8783
# Epoch 87/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0647 - accuracy: 0.9797 - val_loss: 0.6096 - val_accuracy: 0.8780
# Epoch 88/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0630 - accuracy: 0.9800 - val_loss: 0.6176 - val_accuracy: 0.8772
# Epoch 89/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0614 - accuracy: 0.9806 - val_loss: 0.6235 - val_accuracy: 0.8765
# Epoch 90/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0601 - accuracy: 0.9809 - val_loss: 0.6257 - val_accuracy: 0.8771
# Epoch 91/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.0589 - accuracy: 0.9812 - val_loss: 0.6331 - val_accuracy: 0.8773
# Epoch 92/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.0575 - accuracy: 0.9818 - val_loss: 0.6381 - val_accuracy: 0.8766
# Epoch 93/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0563 - accuracy: 0.9819 - val_loss: 0.6421 - val_accuracy: 0.8762
# Epoch 94/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0549 - accuracy: 0.9823 - val_loss: 0.6480 - val_accuracy: 0.8756
# Epoch 95/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0539 - accuracy: 0.9826 - val_loss: 0.6506 - val_accuracy: 0.8764
# Epoch 96/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0528 - accuracy: 0.9830 - val_loss: 0.6536 - val_accuracy: 0.8763
# Epoch 97/100
# 125/125 [==============================] - 3s 24ms/step - loss: 0.0518 - accuracy: 0.9832 - val_loss: 0.6523 - val_accuracy: 0.8770
# Epoch 98/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.0508 - accuracy: 0.9834 - val_loss: 0.6604 - val_accuracy: 0.8772
# Epoch 99/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0501 - accuracy: 0.9837 - val_loss: 0.6616 - val_accuracy: 0.8762
# Epoch 100/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0489 - accuracy: 0.9840 - val_loss: 0.6682 - val_accuracy: 0.8765

# %% [markdown]
# ## **5. Evaluating the Model: Bi-GRU Encoder & GRU Decoder**

# %%
# restore the model and reconstruct the encoder and decoder
model = keras.models.load_model("BiGRU_GRU_model.keras")

# print detailed information about each layer
for index, layer in enumerate(model.layers):
    print(f"Layer index: {index}")
    print(f"Layer name: {layer.name}")
    print(f"Layer type: {type(layer).__name__}")
    print(f"Layer config: {layer.get_config()}")
    print(f"Layer output shape: {layer.output_shape}")
    print()

encoder_inputs = model.input[0]  # input_1
encoder_outputs, forward_h, backward_h = model.layers[1].output  # bidirectional
state_enc_h = Concatenate()([forward_h, backward_h])
encoder_model = Model(encoder_inputs, state_enc_h)

decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = Input(shape=(2 * LATENT_DIM,))
decoder_states_inputs = [decoder_state_input_h]

decoder_gru = model.layers[4] # gru
decoder_outputs, state_dec_h = decoder_gru(
    decoder_inputs, initial_state=decoder_states_inputs
)

decoder_states = [state_dec_h]
decoder_dense = model.layers[5] # dense
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Reverse-lookup token index to decode sequences back to something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())
# Out:
# Layer index: 0
# Layer name: input_1
# Layer type: InputLayer
# Layer config: {'batch_input_shape': (None, None, 70), 'dtype': 'float32', 'sparse': False, 'ragged': False, 'name': 'input_1'}
# Layer output shape: [(None, None, 70)]
#
# Layer index: 1
# Layer name: bidirectional
# Layer type: Bidirectional
# Layer config: {'name': 'bidirectional', 'trainable': True, 'dtype': 'float32', 'layer': {'module': 'keras.layers', 'class_name': 'GRU', 'config': {'name': 'gru', 'trainable': True, 'dtype': 'float32', 'return_sequences': False, 'return_state': True, 'go_backwards': False, 'stateful': False, 'unroll': False, 'time_major': False, 'units': 256, 'activation': 'tanh', 'recurrent_activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'recurrent_initializer': {'module': 'keras.initializers', 'class_name': 'Orthogonal', 'config': {'gain': 1.0, 'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'recurrent_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'recurrent_constraint': None, 'bias_constraint': None, 'dropout': 0.0, 'recurrent_dropout': 0.0, 'implementation': 2, 'reset_after': True}, 'registered_name': None}, 'merge_mode': 'concat'}
# Layer output shape: [(None, 512), (None, 256), (None, 256)]
#
# Layer index: 2
# Layer name: input_2
# Layer type: InputLayer
# Layer config: {'batch_input_shape': (None, None, 91), 'dtype': 'float32', 'sparse': False, 'ragged': False, 'name': 'input_2'}
# Layer output shape: [(None, None, 91)]
#
# Layer index: 3
# Layer name: concatenate
# Layer type: Concatenate
# Layer config: {'name': 'concatenate', 'trainable': True, 'dtype': 'float32', 'axis': -1}
# Layer output shape: (None, 512)
#
# Layer index: 4
# Layer name: gru_1
# Layer type: GRU
# Layer config: {'name': 'gru_1', 'trainable': True, 'dtype': 'float32', 'return_sequences': True, 'return_state': True, 'go_backwards': False, 'stateful': False, 'unroll': False, 'time_major': False, 'units': 512, 'activation': 'tanh', 'recurrent_activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'recurrent_initializer': {'module': 'keras.initializers', 'class_name': 'Orthogonal', 'config': {'gain': 1.0, 'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'recurrent_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'recurrent_constraint': None, 'bias_constraint': None, 'dropout': 0.0, 'recurrent_dropout': 0.0, 'implementation': 2, 'reset_after': True}
# Layer output shape: [(None, None, 512), (None, 512)]
#
# Layer index: 5
# Layer name: dense
# Layer type: Dense
# Layer config: {'name': 'dense', 'trainable': True, 'dtype': 'float32', 'units': 91, 'activation': 'softmax', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# Layer output shape: (None, None, 91)

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq, verbose=0)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))

    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    # Sampling loop for a batch of sequences
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h = decoder_model.predict([target_seq] + [states_value], verbose=0)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length or find stop character.
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = h

    return decoded_sentence

for seq_index in range(20):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)

    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
    print()
# Out:
# Input sentence: Go.
# Decoded sentence: Sartez !
#
#
# Input sentence: Go.
# Decoded sentence: Sartez !
#
#
# Input sentence: Go.
# Decoded sentence: Sartez !
#
#
# Input sentence: Go.
# Decoded sentence: Sartez !
#
#
# Input sentence: Hi.
# Decoded sentence: C'est partit !
#
#
# Input sentence: Hi.
# Decoded sentence: C'est partit !
#
#
# Input sentence: Run!
# Decoded sentence: File !
#
#
# Input sentence: Run!
# Decoded sentence: File !
#
#
# Input sentence: Run!
# Decoded sentence: File !
#
#
# Input sentence: Run!
# Decoded sentence: File !
#
#
# Input sentence: Run!
# Decoded sentence: File !
#
#
# Input sentence: Run!
# Decoded sentence: File !
#
#
# Input sentence: Run!
# Decoded sentence: File !
#
#
# Input sentence: Run!
# Decoded sentence: File !
#
#
# Input sentence: Run.
# Decoded sentence: File !
#
#
# Input sentence: Run.
# Decoded sentence: File !
#
#
# Input sentence: Run.
# Decoded sentence: File !
#
#
# Input sentence: Run.
# Decoded sentence: File !
#
#
# Input sentence: Run.
# Decoded sentence: File !
#
#
# Input sentence: Run.
# Decoded sentence: File !

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

# Calculate BLEU score
def bleu_score(TEST_SIZE):
    smoothie = SmoothingFunction().method4
    bleu_scores = []
    unused_chars = ['\t', '\n', ' ', '\u202f']

    for seq_index in range(TEST_SIZE):
        input_seq = encoder_input_data[seq_index:seq_index + 1]
        decoded_sentence = decode_sequence(input_seq)
        reference = list(filter(lambda x:x not in unused_chars, target_texts[seq_index][1:-1]))
        candidate = list(filter(lambda x:x not in unused_chars, decoded_sentence[:-1]))
        score = sentence_bleu(reference, candidate, smoothing_function=smoothie, weights=(1, 0, 0, 0))
        bleu_scores.append(score)

    return np.mean(bleu_scores)

# Evaluate BLEU score on 100/1000 - 1%/10% of the corpus
print("Average BLEU score on 100 samples:", bleu_score(100))
print("Average BLEU score on 1000 samples:", bleu_score(1000))
# Out:
# Average BLEU score on 100 samples: 0.5422193362193363
# Average BLEU score on 1000 samples: 0.5871321965722542

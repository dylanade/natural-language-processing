# %% [markdown]
# ---
# **Dylan Govender - 221040222 - Assignment III - COMP703**
# ---

# %% [markdown]
# ## **1. Importing the Data**

# %%
# !wget "http://www.manythings.org/anki/fra-eng.zip"
# !unzip fra-eng.zip
# Out:
# --2024-05-24 18:33:04--  http://www.manythings.org/anki/fra-eng.zip
# Resolving www.manythings.org (www.manythings.org)... 173.254.30.110
# Connecting to www.manythings.org (www.manythings.org)|173.254.30.110|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7943074 (7.6M) [application/zip]
# Saving to: ‘fra-eng.zip’
#
# fra-eng.zip         100%[===================>]   7.57M  4.81MB/s    in 1.6s
#
# 2024-05-24 18:33:07 (4.81 MB/s) - ‘fra-eng.zip’ saved [7943074/7943074]
#
# Archive:  fra-eng.zip
#   inflating: _about.txt
#   inflating: fra.txt

# %% [markdown]
# ## **2. Data Preprocessing**

# %%
import numpy as np

# Configuration
MAX_SAMPLES = 10000  # Number of samples to train on.

input_texts = [] # saves first language sentences (input)
target_texts = [] # saves second language sentences (output)
input_characters = set() # saves unique first language words
target_characters = set() # saves unique second language words

with open("//content//fra.txt", "r", encoding="utf-8") as file:
    lines = file.read().split("\n")
    for line in lines[:min(MAX_SAMPLES, len(lines)-1)]:
        input_text, target_text, _ = line.split("\t")

        # "\t" is start sequence character for target sentence
        # "\n" is the end sequence character for target sentence
        target_text = "\t" + target_text + "\n"
        input_texts.append(input_text)
        target_texts.append(target_text)

        for char in input_text:
            if char not in input_characters:
                input_characters.add(char)

        for char in target_text:
            if char not in target_characters:
                target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(text) for text in input_texts])
max_decoder_seq_length = max([len(text) for text in target_texts])

print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)

input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype="float32",
)

decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype="float32",
)

decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype="float32",
)

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[" "]] = 1.0

    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0

        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0

    decoder_input_data[i, t + 1 :, target_token_index[" "]] = 1.0
    decoder_target_data[i, t:, target_token_index[" "]] = 1.0
# Out:
# Number of samples: 10000
# Number of unique input tokens: 70
# Number of unique output tokens: 91
# Max sequence length for inputs: 14
# Max sequence length for outputs: 59

# %% [markdown]
# ## **3. Building the Model: 2-Layered-GRU Encoder & GRU Decoder**

# %%
import tensorflow, keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Reshape, Input, GRU, Embedding, Dense, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Define an input sequence and process it.
LATENT_DIM = 256

# Encoder
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder_gru = GRU(LATENT_DIM, return_sequences=True, return_state=True)
encoder_outputs_1, state_h1 = encoder_gru(encoder_inputs)
encoder_gru_1 = GRU(LATENT_DIM, return_state=True)
encoder_outputs_2, state_h2 = encoder_gru_1(encoder_outputs_1)
state_h = Concatenate()([state_h1, state_h2])
encoder_states = [state_h]

# Decoder
decoder_inputs = Input(shape=(None, num_decoder_tokens))
decoder_gru = GRU(LATENT_DIM*2, return_sequences=True, return_state=True)
decoder_outputs, _ = decoder_gru(decoder_inputs, initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs,  name="2GRU_GRU_model")
model.summary()
# Out:
# Model: "2GRU_GRU_model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, 70)]           0         []
#
#  gru (GRU)                   [(None, None, 256),          251904    ['input_1[0][0]']
#                               (None, 256)]
#
#  gru_1 (GRU)                 [(None, 256),                394752    ['gru[0][0]']
#                               (None, 256)]
#
#  input_2 (InputLayer)        [(None, None, 91)]           0         []
#
#  concatenate (Concatenate)   (None, 512)                  0         ['gru[0][1]',
#                                                                      'gru_1[0][1]']
#
#  gru_2 (GRU)                 [(None, None, 512),          929280    ['input_2[0][0]',
#                               (None, 512)]                           'concatenate[0][0]']
#
#  dense (Dense)               (None, None, 91)             46683     ['gru_2[0][0]']
#
# ==================================================================================================
# Total params: 1622619 (6.19 MB)
# Trainable params: 1622619 (6.19 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## **4. Training the Model: 2-Layered-GRU Encoder & GRU Decoder**

# %%
BATCH_SIZE = 64  # batch size for training
EPOCHS = 100  # number of epochs to train for

model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)

model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_split=0.2,
)

# save model
model.save("2GRU_GRU_model.keras")
# Out:
# Epoch 1/100
# 125/125 [==============================] - 9s 30ms/step - loss: 1.1905 - accuracy: 0.7365 - val_loss: 1.0225 - val_accuracy: 0.7223
# Epoch 2/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.8209 - accuracy: 0.7741 - val_loss: 0.8237 - val_accuracy: 0.7585
# Epoch 3/100
# 125/125 [==============================] - 3s 22ms/step - loss: 0.6877 - accuracy: 0.8030 - val_loss: 0.7376 - val_accuracy: 0.7837
# Epoch 4/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.6337 - accuracy: 0.8151 - val_loss: 0.6880 - val_accuracy: 0.7995
# Epoch 5/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.6040 - accuracy: 0.8229 - val_loss: 0.6704 - val_accuracy: 0.8052
# Epoch 6/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.5809 - accuracy: 0.8295 - val_loss: 0.6435 - val_accuracy: 0.8120
# Epoch 7/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.5631 - accuracy: 0.8338 - val_loss: 0.6243 - val_accuracy: 0.8158
# Epoch 8/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.5481 - accuracy: 0.8383 - val_loss: 0.6129 - val_accuracy: 0.8192
# Epoch 9/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.5351 - accuracy: 0.8418 - val_loss: 0.6018 - val_accuracy: 0.8249
# Epoch 10/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.5225 - accuracy: 0.8455 - val_loss: 0.5881 - val_accuracy: 0.8281
# Epoch 11/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.5104 - accuracy: 0.8489 - val_loss: 0.5766 - val_accuracy: 0.8318
# Epoch 12/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.4978 - accuracy: 0.8524 - val_loss: 0.5687 - val_accuracy: 0.8312
# Epoch 13/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.4843 - accuracy: 0.8562 - val_loss: 0.5621 - val_accuracy: 0.8332
# Epoch 14/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.4720 - accuracy: 0.8601 - val_loss: 0.5454 - val_accuracy: 0.8385
# Epoch 15/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.4612 - accuracy: 0.8629 - val_loss: 0.5435 - val_accuracy: 0.8404
# Epoch 16/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.4503 - accuracy: 0.8659 - val_loss: 0.5267 - val_accuracy: 0.8460
# Epoch 17/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.4405 - accuracy: 0.8689 - val_loss: 0.5187 - val_accuracy: 0.8479
# Epoch 18/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.4309 - accuracy: 0.8716 - val_loss: 0.5105 - val_accuracy: 0.8484
# Epoch 19/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.4220 - accuracy: 0.8740 - val_loss: 0.5069 - val_accuracy: 0.8498
# Epoch 20/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.4133 - accuracy: 0.8762 - val_loss: 0.4980 - val_accuracy: 0.8513
# Epoch 21/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.4047 - accuracy: 0.8789 - val_loss: 0.4976 - val_accuracy: 0.8518
# Epoch 22/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.3955 - accuracy: 0.8812 - val_loss: 0.4884 - val_accuracy: 0.8554
# Epoch 23/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.3869 - accuracy: 0.8837 - val_loss: 0.4774 - val_accuracy: 0.8589
# Epoch 24/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.3780 - accuracy: 0.8863 - val_loss: 0.4677 - val_accuracy: 0.8613
# Epoch 25/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.3696 - accuracy: 0.8888 - val_loss: 0.4652 - val_accuracy: 0.8614
# Epoch 26/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.3612 - accuracy: 0.8915 - val_loss: 0.4578 - val_accuracy: 0.8648
# Epoch 27/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.3531 - accuracy: 0.8937 - val_loss: 0.4526 - val_accuracy: 0.8657
# Epoch 28/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.3452 - accuracy: 0.8957 - val_loss: 0.4509 - val_accuracy: 0.8676
# Epoch 29/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.3378 - accuracy: 0.8981 - val_loss: 0.4433 - val_accuracy: 0.8698
# Epoch 30/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.3297 - accuracy: 0.9002 - val_loss: 0.4469 - val_accuracy: 0.8690
# Epoch 31/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.3228 - accuracy: 0.9025 - val_loss: 0.4401 - val_accuracy: 0.8704
# Epoch 32/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.3157 - accuracy: 0.9047 - val_loss: 0.4399 - val_accuracy: 0.8704
# Epoch 33/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.3089 - accuracy: 0.9067 - val_loss: 0.4364 - val_accuracy: 0.8723
# Epoch 34/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.3016 - accuracy: 0.9089 - val_loss: 0.4306 - val_accuracy: 0.8739
# Epoch 35/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2950 - accuracy: 0.9105 - val_loss: 0.4311 - val_accuracy: 0.8746
# Epoch 36/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.2874 - accuracy: 0.9129 - val_loss: 0.4282 - val_accuracy: 0.8750
# Epoch 37/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.2814 - accuracy: 0.9144 - val_loss: 0.4284 - val_accuracy: 0.8753
# Epoch 38/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2749 - accuracy: 0.9164 - val_loss: 0.4282 - val_accuracy: 0.8763
# Epoch 39/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.2688 - accuracy: 0.9180 - val_loss: 0.4256 - val_accuracy: 0.8771
# Epoch 40/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2625 - accuracy: 0.9202 - val_loss: 0.4310 - val_accuracy: 0.8768
# Epoch 41/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2560 - accuracy: 0.9220 - val_loss: 0.4250 - val_accuracy: 0.8782
# Epoch 42/100
# 125/125 [==============================] - 3s 22ms/step - loss: 0.2497 - accuracy: 0.9238 - val_loss: 0.4234 - val_accuracy: 0.8802
# Epoch 43/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2444 - accuracy: 0.9251 - val_loss: 0.4250 - val_accuracy: 0.8790
# Epoch 44/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2390 - accuracy: 0.9271 - val_loss: 0.4247 - val_accuracy: 0.8800
# Epoch 45/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2327 - accuracy: 0.9287 - val_loss: 0.4278 - val_accuracy: 0.8806
# Epoch 46/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2274 - accuracy: 0.9300 - val_loss: 0.4288 - val_accuracy: 0.8809
# Epoch 47/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2215 - accuracy: 0.9320 - val_loss: 0.4295 - val_accuracy: 0.8803
# Epoch 48/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2164 - accuracy: 0.9336 - val_loss: 0.4295 - val_accuracy: 0.8813
# Epoch 49/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.2112 - accuracy: 0.9349 - val_loss: 0.4355 - val_accuracy: 0.8807
# Epoch 50/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2062 - accuracy: 0.9364 - val_loss: 0.4340 - val_accuracy: 0.8806
# Epoch 51/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.2012 - accuracy: 0.9380 - val_loss: 0.4364 - val_accuracy: 0.8813
# Epoch 52/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1965 - accuracy: 0.9394 - val_loss: 0.4393 - val_accuracy: 0.8821
# Epoch 53/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.1914 - accuracy: 0.9409 - val_loss: 0.4408 - val_accuracy: 0.8824
# Epoch 54/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1873 - accuracy: 0.9421 - val_loss: 0.4449 - val_accuracy: 0.8813
# Epoch 55/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1822 - accuracy: 0.9438 - val_loss: 0.4425 - val_accuracy: 0.8826
# Epoch 56/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1777 - accuracy: 0.9451 - val_loss: 0.4486 - val_accuracy: 0.8821
# Epoch 57/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1736 - accuracy: 0.9459 - val_loss: 0.4538 - val_accuracy: 0.8814
# Epoch 58/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1699 - accuracy: 0.9472 - val_loss: 0.4570 - val_accuracy: 0.8813
# Epoch 59/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1657 - accuracy: 0.9487 - val_loss: 0.4594 - val_accuracy: 0.8821
# Epoch 60/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1616 - accuracy: 0.9500 - val_loss: 0.4638 - val_accuracy: 0.8815
# Epoch 61/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1582 - accuracy: 0.9507 - val_loss: 0.4649 - val_accuracy: 0.8824
# Epoch 62/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1545 - accuracy: 0.9520 - val_loss: 0.4705 - val_accuracy: 0.8812
# Epoch 63/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1514 - accuracy: 0.9528 - val_loss: 0.4724 - val_accuracy: 0.8819
# Epoch 64/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1480 - accuracy: 0.9539 - val_loss: 0.4792 - val_accuracy: 0.8806
# Epoch 65/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1451 - accuracy: 0.9546 - val_loss: 0.4840 - val_accuracy: 0.8815
# Epoch 66/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1419 - accuracy: 0.9557 - val_loss: 0.4829 - val_accuracy: 0.8824
# Epoch 67/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1386 - accuracy: 0.9564 - val_loss: 0.4889 - val_accuracy: 0.8818
# Epoch 68/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1362 - accuracy: 0.9572 - val_loss: 0.4969 - val_accuracy: 0.8812
# Epoch 69/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1332 - accuracy: 0.9580 - val_loss: 0.5010 - val_accuracy: 0.8806
# Epoch 70/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1308 - accuracy: 0.9590 - val_loss: 0.4990 - val_accuracy: 0.8822
# Epoch 71/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1286 - accuracy: 0.9595 - val_loss: 0.5052 - val_accuracy: 0.8810
# Epoch 72/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1259 - accuracy: 0.9603 - val_loss: 0.5061 - val_accuracy: 0.8813
# Epoch 73/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1237 - accuracy: 0.9606 - val_loss: 0.5130 - val_accuracy: 0.8810
# Epoch 74/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1212 - accuracy: 0.9615 - val_loss: 0.5152 - val_accuracy: 0.8808
# Epoch 75/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1189 - accuracy: 0.9621 - val_loss: 0.5188 - val_accuracy: 0.8812
# Epoch 76/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.1167 - accuracy: 0.9627 - val_loss: 0.5289 - val_accuracy: 0.8800
# Epoch 77/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1152 - accuracy: 0.9633 - val_loss: 0.5340 - val_accuracy: 0.8785
# Epoch 78/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1131 - accuracy: 0.9639 - val_loss: 0.5329 - val_accuracy: 0.8796
# Epoch 79/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1110 - accuracy: 0.9643 - val_loss: 0.5360 - val_accuracy: 0.8806
# Epoch 80/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1093 - accuracy: 0.9647 - val_loss: 0.5393 - val_accuracy: 0.8796
# Epoch 81/100
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1079 - accuracy: 0.9651 - val_loss: 0.5426 - val_accuracy: 0.8798
# Epoch 82/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1055 - accuracy: 0.9658 - val_loss: 0.5457 - val_accuracy: 0.8800
# Epoch 83/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1039 - accuracy: 0.9662 - val_loss: 0.5525 - val_accuracy: 0.8795
# Epoch 84/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1023 - accuracy: 0.9667 - val_loss: 0.5614 - val_accuracy: 0.8798
# Epoch 85/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1008 - accuracy: 0.9672 - val_loss: 0.5617 - val_accuracy: 0.8789
# Epoch 86/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.0994 - accuracy: 0.9674 - val_loss: 0.5637 - val_accuracy: 0.8795
# Epoch 87/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.0980 - accuracy: 0.9680 - val_loss: 0.5666 - val_accuracy: 0.8796
# Epoch 88/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.0965 - accuracy: 0.9683 - val_loss: 0.5687 - val_accuracy: 0.8788
# Epoch 89/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0952 - accuracy: 0.9688 - val_loss: 0.5755 - val_accuracy: 0.8781
# Epoch 90/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0937 - accuracy: 0.9692 - val_loss: 0.5771 - val_accuracy: 0.8792
# Epoch 91/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0924 - accuracy: 0.9697 - val_loss: 0.5818 - val_accuracy: 0.8775
# Epoch 92/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.0908 - accuracy: 0.9701 - val_loss: 0.5843 - val_accuracy: 0.8784
# Epoch 93/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.0897 - accuracy: 0.9703 - val_loss: 0.5868 - val_accuracy: 0.8785
# Epoch 94/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.0889 - accuracy: 0.9706 - val_loss: 0.5926 - val_accuracy: 0.8779
# Epoch 95/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0873 - accuracy: 0.9710 - val_loss: 0.5992 - val_accuracy: 0.8767
# Epoch 96/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.0860 - accuracy: 0.9713 - val_loss: 0.6048 - val_accuracy: 0.8759
# Epoch 97/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.0852 - accuracy: 0.9718 - val_loss: 0.5979 - val_accuracy: 0.8776
# Epoch 98/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.0838 - accuracy: 0.9717 - val_loss: 0.6046 - val_accuracy: 0.8781
# Epoch 99/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.0824 - accuracy: 0.9726 - val_loss: 0.6113 - val_accuracy: 0.8768
# Epoch 100/100
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0818 - accuracy: 0.9725 - val_loss: 0.6114 - val_accuracy: 0.8772

# %% [markdown]
# ## **5. Evaluating the Model: 2-Layered-GRU Encoder & GRU Decoder**

# %%
# restore the model and reconstruct the encoder and decoder
model = keras.models.load_model("2GRU_GRU_model.keras")

# print detailed information about each layer
for index, layer in enumerate(model.layers):
    print(f"Layer index: {index}")
    print(f"Layer name: {layer.name}")
    print(f"Layer type: {type(layer).__name__}")
    print(f"Layer config: {layer.get_config()}")
    print(f"Layer output shape: {layer.output_shape}")
    print()

encoder_inputs = model.input[0]  # input_1
encoder_output_1, state_h1 = model.layers[1].output # gru
encoder_output_1, state_h2 = model.layers[2].output # gru_1

state_h = Concatenate()([state_h1, state_h2])
encoder_states = [state_h]
encoder_model = Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = Input(shape=(LATENT_DIM*2,))
decoder_states_inputs = [decoder_state_input_h]

gru_decoder = model.layers[5] # gru_2
decoder_outputs, state_dec_h = gru_decoder( # gru_2
    decoder_inputs, initial_state=decoder_states_inputs
)

decoder_states = [state_dec_h]
decoder_outputs = model.layers[6](decoder_outputs) # dense
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Reverse-lookup token index to decode sequences back to something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())
# Out:
# Layer index: 0
# Layer name: input_1
# Layer type: InputLayer
# Layer config: {'batch_input_shape': (None, None, 70), 'dtype': 'float32', 'sparse': False, 'ragged': False, 'name': 'input_1'}
# Layer output shape: [(None, None, 70)]
#
# Layer index: 1
# Layer name: gru
# Layer type: GRU
# Layer config: {'name': 'gru', 'trainable': True, 'dtype': 'float32', 'return_sequences': True, 'return_state': True, 'go_backwards': False, 'stateful': False, 'unroll': False, 'time_major': False, 'units': 256, 'activation': 'tanh', 'recurrent_activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'recurrent_initializer': {'module': 'keras.initializers', 'class_name': 'Orthogonal', 'config': {'gain': 1.0, 'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'recurrent_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'recurrent_constraint': None, 'bias_constraint': None, 'dropout': 0.0, 'recurrent_dropout': 0.0, 'implementation': 2, 'reset_after': True}
# Layer output shape: [(None, None, 256), (None, 256)]
#
# Layer index: 2
# Layer name: gru_1
# Layer type: GRU
# Layer config: {'name': 'gru_1', 'trainable': True, 'dtype': 'float32', 'return_sequences': False, 'return_state': True, 'go_backwards': False, 'stateful': False, 'unroll': False, 'time_major': False, 'units': 256, 'activation': 'tanh', 'recurrent_activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'recurrent_initializer': {'module': 'keras.initializers', 'class_name': 'Orthogonal', 'config': {'gain': 1.0, 'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'recurrent_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'recurrent_constraint': None, 'bias_constraint': None, 'dropout': 0.0, 'recurrent_dropout': 0.0, 'implementation': 2, 'reset_after': True}
# Layer output shape: [(None, 256), (None, 256)]
#
# Layer index: 3
# Layer name: input_2
# Layer type: InputLayer
# Layer config: {'batch_input_shape': (None, None, 91), 'dtype': 'float32', 'sparse': False, 'ragged': False, 'name': 'input_2'}
# Layer output shape: [(None, None, 91)]
#
# Layer index: 4
# Layer name: concatenate
# Layer type: Concatenate
# Layer config: {'name': 'concatenate', 'trainable': True, 'dtype': 'float32', 'axis': -1}
# Layer output shape: (None, 512)
#
# Layer index: 5
# Layer name: gru_2
# Layer type: GRU
# Layer config: {'name': 'gru_2', 'trainable': True, 'dtype': 'float32', 'return_sequences': True, 'return_state': True, 'go_backwards': False, 'stateful': False, 'unroll': False, 'time_major': False, 'units': 512, 'activation': 'tanh', 'recurrent_activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'recurrent_initializer': {'module': 'keras.initializers', 'class_name': 'Orthogonal', 'config': {'gain': 1.0, 'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'recurrent_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'recurrent_constraint': None, 'bias_constraint': None, 'dropout': 0.0, 'recurrent_dropout': 0.0, 'implementation': 2, 'reset_after': True}
# Layer output shape: [(None, None, 512), (None, 512)]
#
# Layer index: 6
# Layer name: dense
# Layer type: Dense
# Layer config: {'name': 'dense', 'trainable': True, 'dtype': 'float32', 'units': 91, 'activation': 'softmax', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# Layer output shape: (None, None, 91)

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq, verbose=0)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))

    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    # Sampling loop for a batch of sequences
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h = decoder_model.predict([target_seq] + [states_value], verbose=0)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length or find stop character.
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = h

    return decoded_sentence

# Test decoding
for seq_index in range(20):
    # Take one sequence (part of the training set) for trying out decoding
    input_seq = encoder_input_data[seq_index:seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)

    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
    print()
# Out:
# Input sentence: Go.
# Decoded sentence: Cours !
#
#
# Input sentence: Go.
# Decoded sentence: Cours !
#
#
# Input sentence: Go.
# Decoded sentence: Cours !
#
#
# Input sentence: Go.
# Decoded sentence: Cours !
#
#
# Input sentence: Hi.
# Decoded sentence: Salut !
#
#
# Input sentence: Hi.
# Decoded sentence: Salut !
#
#
# Input sentence: Run!
# Decoded sentence: Fuyons !
#
#
# Input sentence: Run!
# Decoded sentence: Fuyons !
#
#
# Input sentence: Run!
# Decoded sentence: Fuyons !
#
#
# Input sentence: Run!
# Decoded sentence: Fuyons !
#
#
# Input sentence: Run!
# Decoded sentence: Fuyons !
#
#
# Input sentence: Run!
# Decoded sentence: Fuyons !
#
#
# Input sentence: Run!
# Decoded sentence: Fuyons !
#
#
# Input sentence: Run!
# Decoded sentence: Fuyons !
#
#
# Input sentence: Run.
# Decoded sentence: Fuyons !
#
#
# Input sentence: Run.
# Decoded sentence: Fuyons !
#
#
# Input sentence: Run.
# Decoded sentence: Fuyons !
#
#
# Input sentence: Run.
# Decoded sentence: Fuyons !
#
#
# Input sentence: Run.
# Decoded sentence: Fuyons !
#
#
# Input sentence: Run.
# Decoded sentence: Fuyons !

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

# Calculate BLEU score
def bleu_score(TEST_SIZE):
    smoothie = SmoothingFunction().method4
    bleu_scores = []
    unused_chars = ['\t', '\n', ' ', '\u202f']

    for seq_index in range(TEST_SIZE):
        input_seq = encoder_input_data[seq_index:seq_index + 1]
        decoded_sentence = decode_sequence(input_seq)
        reference = list(filter(lambda x:x not in unused_chars, target_texts[seq_index][1:-1]))
        candidate = list(filter(lambda x:x not in unused_chars, decoded_sentence[:-1]))
        score = sentence_bleu(reference, candidate, smoothing_function=smoothie, weights=(1, 0, 0, 0))
        bleu_scores.append(score)

    return np.mean(bleu_scores)

# Evaluate BLEU score on 100/1000 - 1%/10% of the corpus
print("Average BLEU score on 100 samples:", bleu_score(100))
print("Average BLEU score on 1000 samples:", bleu_score(1000))
# Out:
# Average BLEU score on 100 samples: 0.5255511351393705
# Average BLEU score on 1000 samples: 0.5065846916517074

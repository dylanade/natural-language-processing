# %% [markdown]
# ---
# **Dylan Govender - 221040222 - Assignment III - COMP703**
# ---

# %% [markdown]
# ## **1. Importing the Data**

# %%
# !wget "http://www.manythings.org/anki/fra-eng.zip"
# !unzip fra-eng.zip
# Out:
# --2024-05-24 16:34:27--  http://www.manythings.org/anki/fra-eng.zip
# Resolving www.manythings.org (www.manythings.org)... 173.254.30.110
# Connecting to www.manythings.org (www.manythings.org)|173.254.30.110|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7943074 (7.6M) [application/zip]
# Saving to: ‘fra-eng.zip’
#
# fra-eng.zip         100%[===================>]   7.57M  20.7MB/s    in 0.4s
#
# 2024-05-24 16:34:27 (20.7 MB/s) - ‘fra-eng.zip’ saved [7943074/7943074]
#
# Archive:  fra-eng.zip
#   inflating: _about.txt
#   inflating: fra.txt

# %% [markdown]
# ## **2. Data Preprocessing**

# %%
import numpy as np

# Configuration
MAX_SAMPLES = 10000  # Number of samples to train on.

input_texts = [] # saves first language sentences (input)
target_texts = [] # saves second language sentences (output)
input_characters = set() # saves unique first language words
target_characters = set() # saves unique second language words

with open("//content//fra.txt", "r", encoding="utf-8") as file:
    lines = file.read().split("\n")
    for line in lines[:min(MAX_SAMPLES, len(lines)-1)]:
        input_text, target_text, _ = line.split("\t")

        # "\t" is start sequence character for target sentence
        # "\n" is the end sequence character for target sentence
        target_text = "\t" + target_text + "\n"
        input_texts.append(input_text)
        target_texts.append(target_text)

        for char in input_text:
            if char not in input_characters:
                input_characters.add(char)

        for char in target_text:
            if char not in target_characters:
                target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(text) for text in input_texts])
max_decoder_seq_length = max([len(text) for text in target_texts])

print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)

input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype="float32",
)

decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype="float32",
)

decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype="float32",
)

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[" "]] = 1.0

    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0

        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0

    decoder_input_data[i, t + 1 :, target_token_index[" "]] = 1.0
    decoder_target_data[i, t:, target_token_index[" "]] = 1.0
# Out:
# Number of samples: 10000
# Number of unique input tokens: 70
# Number of unique output tokens: 91
# Max sequence length for inputs: 14
# Max sequence length for outputs: 59

# %% [markdown]
# ## **3. Building the Model: Bi-LSTM Encoder & LSTM Decoder**

# %%
import tensorflow, keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Reshape, Input, Bidirectional, LSTM, Embedding, Dense, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Define an input sequence and process it.
LATENT_DIM = 256

# Encoder
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = Bidirectional(LSTM(LATENT_DIM, return_state=True))
encoder_outputs, forward_h, forward_c, backward_h, backward_c = encoder(encoder_inputs)
state_h = Concatenate()([forward_h, backward_h])
state_c = Concatenate()([forward_c, backward_c])

# Decoder
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(2*LATENT_DIM, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs, name="BiLSTM_LSTM_model")
model.summary()
# Out:
# Model: "BiLSTM_LSTM_model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, 70)]           0         []
#
#  bidirectional (Bidirection  [(None, 512),                669696    ['input_1[0][0]']
#  al)                          (None, 256),
#                               (None, 256),
#                               (None, 256),
#                               (None, 256)]
#
#  input_2 (InputLayer)        [(None, None, 91)]           0         []
#
#  concatenate (Concatenate)   (None, 512)                  0         ['bidirectional[0][1]',
#                                                                      'bidirectional[0][3]']
#
#  concatenate_1 (Concatenate  (None, 512)                  0         ['bidirectional[0][2]',
#  )                                                                   'bidirectional[0][4]']
#
#  lstm_1 (LSTM)               [(None, None, 512),          1236992   ['input_2[0][0]',
#                               (None, 512),                           'concatenate[0][0]',
#                               (None, 512)]                           'concatenate_1[0][0]']
#
#  dense (Dense)               (None, None, 91)             46683     ['lstm_1[0][0]']
#
# ==================================================================================================
# Total params: 1953371 (7.45 MB)
# Trainable params: 1953371 (7.45 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ## **4. Training the Model: Bi-LSTM Encoder & LSTM Decoder**

# %%
BATCH_SIZE = 64  # batch size for training
EPOCHS = 100  # number of epochs to train for

model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)

model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_split=0.2,
)

# save model
model.save("BiLSTM_LSTM_model.keras")
# Out:
# Epoch 1/100
# 125/125 [==============================] - 9s 39ms/step - loss: 1.2389 - accuracy: 0.7273 - val_loss: 1.2289 - val_accuracy: 0.7114
# Epoch 2/100
# 125/125 [==============================] - 3s 23ms/step - loss: 0.9609 - accuracy: 0.7473 - val_loss: 0.9939 - val_accuracy: 0.7228
# Epoch 3/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.8672 - accuracy: 0.7626 - val_loss: 0.8979 - val_accuracy: 0.7502
# Epoch 4/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.7691 - accuracy: 0.7856 - val_loss: 0.8061 - val_accuracy: 0.7630
# Epoch 5/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.6995 - accuracy: 0.7988 - val_loss: 0.7264 - val_accuracy: 0.7905
# Epoch 6/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.6360 - accuracy: 0.8151 - val_loss: 0.6886 - val_accuracy: 0.7994
# Epoch 7/100
# 125/125 [==============================] - 3s 24ms/step - loss: 0.6119 - accuracy: 0.8218 - val_loss: 0.6635 - val_accuracy: 0.8085
# Epoch 8/100
# 125/125 [==============================] - 3s 22ms/step - loss: 0.5823 - accuracy: 0.8284 - val_loss: 0.6414 - val_accuracy: 0.8117
# Epoch 9/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.5629 - accuracy: 0.8339 - val_loss: 0.6237 - val_accuracy: 0.8177
# Epoch 10/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.5447 - accuracy: 0.8399 - val_loss: 0.6009 - val_accuracy: 0.8224
# Epoch 11/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.5273 - accuracy: 0.8450 - val_loss: 0.5858 - val_accuracy: 0.8286
# Epoch 12/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.5116 - accuracy: 0.8492 - val_loss: 0.5748 - val_accuracy: 0.8329
# Epoch 13/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.4976 - accuracy: 0.8537 - val_loss: 0.5727 - val_accuracy: 0.8308
# Epoch 14/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.4836 - accuracy: 0.8570 - val_loss: 0.5494 - val_accuracy: 0.8372
# Epoch 15/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.4715 - accuracy: 0.8606 - val_loss: 0.5389 - val_accuracy: 0.8429
# Epoch 16/100
# 125/125 [==============================] - 3s 23ms/step - loss: 0.4599 - accuracy: 0.8638 - val_loss: 0.5332 - val_accuracy: 0.8415
# Epoch 17/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.4484 - accuracy: 0.8666 - val_loss: 0.5200 - val_accuracy: 0.8463
# Epoch 18/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.4377 - accuracy: 0.8695 - val_loss: 0.5178 - val_accuracy: 0.8446
# Epoch 19/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.4271 - accuracy: 0.8731 - val_loss: 0.5182 - val_accuracy: 0.8466
# Epoch 20/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.4175 - accuracy: 0.8759 - val_loss: 0.5060 - val_accuracy: 0.8499
# Epoch 21/100
# 125/125 [==============================] - 3s 22ms/step - loss: 0.4074 - accuracy: 0.8793 - val_loss: 0.4928 - val_accuracy: 0.8557
# Epoch 22/100
# 125/125 [==============================] - 3s 22ms/step - loss: 0.3987 - accuracy: 0.8815 - val_loss: 0.4863 - val_accuracy: 0.8570
# Epoch 23/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.3895 - accuracy: 0.8842 - val_loss: 0.4880 - val_accuracy: 0.8556
# Epoch 24/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.3808 - accuracy: 0.8869 - val_loss: 0.4801 - val_accuracy: 0.8591
# Epoch 25/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.3727 - accuracy: 0.8891 - val_loss: 0.4705 - val_accuracy: 0.8618
# Epoch 26/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.3648 - accuracy: 0.8913 - val_loss: 0.4707 - val_accuracy: 0.8622
# Epoch 27/100
# 125/125 [==============================] - 3s 24ms/step - loss: 0.3568 - accuracy: 0.8937 - val_loss: 0.4645 - val_accuracy: 0.8644
# Epoch 28/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.3487 - accuracy: 0.8962 - val_loss: 0.4632 - val_accuracy: 0.8646
# Epoch 29/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.3416 - accuracy: 0.8981 - val_loss: 0.4605 - val_accuracy: 0.8651
# Epoch 30/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.3336 - accuracy: 0.9004 - val_loss: 0.4583 - val_accuracy: 0.8657
# Epoch 31/100
# 125/125 [==============================] - 3s 22ms/step - loss: 0.3268 - accuracy: 0.9026 - val_loss: 0.4548 - val_accuracy: 0.8668
# Epoch 32/100
# 125/125 [==============================] - 3s 23ms/step - loss: 0.3191 - accuracy: 0.9045 - val_loss: 0.4526 - val_accuracy: 0.8680
# Epoch 33/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.3124 - accuracy: 0.9063 - val_loss: 0.4584 - val_accuracy: 0.8667
# Epoch 34/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.3053 - accuracy: 0.9086 - val_loss: 0.4513 - val_accuracy: 0.8685
# Epoch 35/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.2989 - accuracy: 0.9104 - val_loss: 0.4444 - val_accuracy: 0.8716
# Epoch 36/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2915 - accuracy: 0.9125 - val_loss: 0.4509 - val_accuracy: 0.8697
# Epoch 37/100
# 125/125 [==============================] - 3s 24ms/step - loss: 0.2850 - accuracy: 0.9147 - val_loss: 0.4455 - val_accuracy: 0.8719
# Epoch 38/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2787 - accuracy: 0.9165 - val_loss: 0.4481 - val_accuracy: 0.8712
# Epoch 39/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2720 - accuracy: 0.9182 - val_loss: 0.4457 - val_accuracy: 0.8721
# Epoch 40/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2649 - accuracy: 0.9205 - val_loss: 0.4463 - val_accuracy: 0.8722
# Epoch 41/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2586 - accuracy: 0.9222 - val_loss: 0.4479 - val_accuracy: 0.8729
# Epoch 42/100
# 125/125 [==============================] - 3s 22ms/step - loss: 0.2528 - accuracy: 0.9241 - val_loss: 0.4478 - val_accuracy: 0.8734
# Epoch 43/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2464 - accuracy: 0.9260 - val_loss: 0.4537 - val_accuracy: 0.8723
# Epoch 44/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2405 - accuracy: 0.9278 - val_loss: 0.4505 - val_accuracy: 0.8733
# Epoch 45/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2334 - accuracy: 0.9297 - val_loss: 0.4521 - val_accuracy: 0.8738
# Epoch 46/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2276 - accuracy: 0.9315 - val_loss: 0.4570 - val_accuracy: 0.8734
# Epoch 47/100
# 125/125 [==============================] - 3s 23ms/step - loss: 0.2227 - accuracy: 0.9329 - val_loss: 0.4591 - val_accuracy: 0.8743
# Epoch 48/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.2163 - accuracy: 0.9349 - val_loss: 0.4581 - val_accuracy: 0.8745
# Epoch 49/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2107 - accuracy: 0.9367 - val_loss: 0.4643 - val_accuracy: 0.8741
# Epoch 50/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.2052 - accuracy: 0.9385 - val_loss: 0.4625 - val_accuracy: 0.8743
# Epoch 51/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1996 - accuracy: 0.9401 - val_loss: 0.4693 - val_accuracy: 0.8736
# Epoch 52/100
# 125/125 [==============================] - 3s 26ms/step - loss: 0.1942 - accuracy: 0.9415 - val_loss: 0.4737 - val_accuracy: 0.8740
# Epoch 53/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.1888 - accuracy: 0.9433 - val_loss: 0.4785 - val_accuracy: 0.8739
# Epoch 54/100
# 125/125 [==============================] - 2s 20ms/step - loss: 0.1834 - accuracy: 0.9449 - val_loss: 0.4792 - val_accuracy: 0.8736
# Epoch 55/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1796 - accuracy: 0.9461 - val_loss: 0.4785 - val_accuracy: 0.8746
# Epoch 56/100
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1741 - accuracy: 0.9474 - val_loss: 0.4819 - val_accuracy: 0.8740
# Epoch 57/100
# 125/125 [==============================] - 3s 22ms/step - loss: 0.1691 - accuracy: 0.9491 - val_loss: 0.4851 - val_accuracy: 0.8737
# Epoch 58/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1646 - accuracy: 0.9504 - val_loss: 0.4909 - val_accuracy: 0.8743
# Epoch 59/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1596 - accuracy: 0.9520 - val_loss: 0.4933 - val_accuracy: 0.8743
# Epoch 60/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1554 - accuracy: 0.9531 - val_loss: 0.4979 - val_accuracy: 0.8747
# Epoch 61/100
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1517 - accuracy: 0.9543 - val_loss: 0.4999 - val_accuracy: 0.8734
# Epoch 62/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.1470 - accuracy: 0.9559 - val_loss: 0.5028 - val_accuracy: 0.8739
# Epoch 63/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.1433 - accuracy: 0.9570 - val_loss: 0.5105 - val_accuracy: 0.8733
# Epoch 64/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.1392 - accuracy: 0.9583 - val_loss: 0.5124 - val_accuracy: 0.8732
# Epoch 65/100
# 125/125 [==============================] - 3s 22ms/step - loss: 0.1354 - accuracy: 0.9594 - val_loss: 0.5276 - val_accuracy: 0.8710
# Epoch 66/100
# 125/125 [==============================] - 3s 25ms/step - loss: 0.1313 - accuracy: 0.9607 - val_loss: 0.5278 - val_accuracy: 0.8726
# Epoch 67/100
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1276 - accuracy: 0.9615 - val_loss: 0.5291 - val_accuracy: 0.8728
# Epoch 68/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.1243 - accuracy: 0.9625 - val_loss: 0.5315 - val_accuracy: 0.8734
# Epoch 69/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.1206 - accuracy: 0.9638 - val_loss: 0.5402 - val_accuracy: 0.8722
# Epoch 70/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.1177 - accuracy: 0.9645 - val_loss: 0.5423 - val_accuracy: 0.8733
# Epoch 71/100
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1144 - accuracy: 0.9656 - val_loss: 0.5464 - val_accuracy: 0.8724
# Epoch 72/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.1115 - accuracy: 0.9664 - val_loss: 0.5542 - val_accuracy: 0.8729
# Epoch 73/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.1084 - accuracy: 0.9674 - val_loss: 0.5593 - val_accuracy: 0.8720
# Epoch 74/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.1050 - accuracy: 0.9685 - val_loss: 0.5650 - val_accuracy: 0.8725
# Epoch 75/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.1027 - accuracy: 0.9689 - val_loss: 0.5660 - val_accuracy: 0.8722
# Epoch 76/100
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1000 - accuracy: 0.9699 - val_loss: 0.5720 - val_accuracy: 0.8719
# Epoch 77/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.0971 - accuracy: 0.9707 - val_loss: 0.5761 - val_accuracy: 0.8727
# Epoch 78/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.0945 - accuracy: 0.9715 - val_loss: 0.5806 - val_accuracy: 0.8718
# Epoch 79/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.0927 - accuracy: 0.9717 - val_loss: 0.5884 - val_accuracy: 0.8702
# Epoch 80/100
# 125/125 [==============================] - 3s 23ms/step - loss: 0.0899 - accuracy: 0.9727 - val_loss: 0.5903 - val_accuracy: 0.8717
# Epoch 81/100
# 125/125 [==============================] - 3s 22ms/step - loss: 0.0873 - accuracy: 0.9736 - val_loss: 0.5985 - val_accuracy: 0.8709
# Epoch 82/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.0858 - accuracy: 0.9738 - val_loss: 0.6019 - val_accuracy: 0.8713
# Epoch 83/100
# 125/125 [==============================] - 3s 22ms/step - loss: 0.0832 - accuracy: 0.9749 - val_loss: 0.6071 - val_accuracy: 0.8703
# Epoch 84/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.0813 - accuracy: 0.9753 - val_loss: 0.6094 - val_accuracy: 0.8717
# Epoch 85/100
# 125/125 [==============================] - 3s 24ms/step - loss: 0.0794 - accuracy: 0.9758 - val_loss: 0.6122 - val_accuracy: 0.8708
# Epoch 86/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.0776 - accuracy: 0.9762 - val_loss: 0.6145 - val_accuracy: 0.8711
# Epoch 87/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.0757 - accuracy: 0.9769 - val_loss: 0.6270 - val_accuracy: 0.8695
# Epoch 88/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.0735 - accuracy: 0.9774 - val_loss: 0.6297 - val_accuracy: 0.8696
# Epoch 89/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.0722 - accuracy: 0.9781 - val_loss: 0.6354 - val_accuracy: 0.8704
# Epoch 90/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.0705 - accuracy: 0.9785 - val_loss: 0.6369 - val_accuracy: 0.8708
# Epoch 91/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.0686 - accuracy: 0.9789 - val_loss: 0.6369 - val_accuracy: 0.8709
# Epoch 92/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.0672 - accuracy: 0.9793 - val_loss: 0.6443 - val_accuracy: 0.8700
# Epoch 93/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.0662 - accuracy: 0.9796 - val_loss: 0.6520 - val_accuracy: 0.8701
# Epoch 94/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.0643 - accuracy: 0.9801 - val_loss: 0.6502 - val_accuracy: 0.8704
# Epoch 95/100
# 125/125 [==============================] - 3s 25ms/step - loss: 0.0628 - accuracy: 0.9806 - val_loss: 0.6621 - val_accuracy: 0.8696
# Epoch 96/100
# 125/125 [==============================] - 3s 23ms/step - loss: 0.0620 - accuracy: 0.9809 - val_loss: 0.6663 - val_accuracy: 0.8688
# Epoch 97/100
# 125/125 [==============================] - 3s 21ms/step - loss: 0.0604 - accuracy: 0.9811 - val_loss: 0.6605 - val_accuracy: 0.8705
# Epoch 98/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.0591 - accuracy: 0.9815 - val_loss: 0.6693 - val_accuracy: 0.8685
# Epoch 99/100
# 125/125 [==============================] - 3s 20ms/step - loss: 0.0582 - accuracy: 0.9818 - val_loss: 0.6756 - val_accuracy: 0.8692
# Epoch 100/100
# 125/125 [==============================] - 3s 25ms/step - loss: 0.0570 - accuracy: 0.9822 - val_loss: 0.6697 - val_accuracy: 0.8701

# %% [markdown]
# ## **5. Evaluating the Model: Bi-LSTM Encoder & LSTM Decoder**

# %%
# load the saved model
model = keras.models.load_model("BiLSTM_LSTM_model.keras")

# print detailed information about each layer
for index, layer in enumerate(model.layers):
    print(f"Layer index: {index}")
    print(f"Layer name: {layer.name}")
    print(f"Layer type: {type(layer).__name__}")
    print(f"Layer config: {layer.get_config()}")
    print(f"Layer output shape: {layer.output_shape}")
    print()

LATENT_DIM = 256

# Encoder model
encoder_inputs = model.input[0]  # input_1

_, forward_h, forward_c, backward_h, backward_c = model.layers[1].output  # bidirectional
state_h = Concatenate()([forward_h, backward_h])
state_c = Concatenate()([forward_c, backward_c])
encoder_states = [state_h, state_c]
encoder_model = Model(encoder_inputs, encoder_states)

# Decoder model
decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = Input(shape=(2*LATENT_DIM,))
decoder_state_input_c = Input(shape=(2*LATENT_DIM,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

decoder_lstm = model.layers[5]  # lstm_1
decoder_outputs, state_dec_h, state_dec_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs
)

decoder_states = [state_dec_h, state_dec_c]

decoder_dense = model.layers[6]  # dense
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Reverse-lookup token index to decode sequences back to something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())
# Out:
# Layer index: 0
# Layer name: input_1
# Layer type: InputLayer
# Layer config: {'batch_input_shape': (None, None, 70), 'dtype': 'float32', 'sparse': False, 'ragged': False, 'name': 'input_1'}
# Layer output shape: [(None, None, 70)]
#
# Layer index: 1
# Layer name: bidirectional
# Layer type: Bidirectional
# Layer config: {'name': 'bidirectional', 'trainable': True, 'dtype': 'float32', 'layer': {'module': 'keras.layers', 'class_name': 'LSTM', 'config': {'name': 'lstm', 'trainable': True, 'dtype': 'float32', 'return_sequences': False, 'return_state': True, 'go_backwards': False, 'stateful': False, 'unroll': False, 'time_major': False, 'units': 256, 'activation': 'tanh', 'recurrent_activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'recurrent_initializer': {'module': 'keras.initializers', 'class_name': 'Orthogonal', 'config': {'gain': 1.0, 'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'unit_forget_bias': True, 'kernel_regularizer': None, 'recurrent_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'recurrent_constraint': None, 'bias_constraint': None, 'dropout': 0.0, 'recurrent_dropout': 0.0, 'implementation': 2}, 'registered_name': None}, 'merge_mode': 'concat'}
# Layer output shape: [(None, 512), (None, 256), (None, 256), (None, 256), (None, 256)]
#
# Layer index: 2
# Layer name: input_2
# Layer type: InputLayer
# Layer config: {'batch_input_shape': (None, None, 91), 'dtype': 'float32', 'sparse': False, 'ragged': False, 'name': 'input_2'}
# Layer output shape: [(None, None, 91)]
#
# Layer index: 3
# Layer name: concatenate
# Layer type: Concatenate
# Layer config: {'name': 'concatenate', 'trainable': True, 'dtype': 'float32', 'axis': -1}
# Layer output shape: (None, 512)
#
# Layer index: 4
# Layer name: concatenate_1
# Layer type: Concatenate
# Layer config: {'name': 'concatenate_1', 'trainable': True, 'dtype': 'float32', 'axis': -1}
# Layer output shape: (None, 512)
#
# Layer index: 5
# Layer name: lstm_1
# Layer type: LSTM
# Layer config: {'name': 'lstm_1', 'trainable': True, 'dtype': 'float32', 'return_sequences': True, 'return_state': True, 'go_backwards': False, 'stateful': False, 'unroll': False, 'time_major': False, 'units': 512, 'activation': 'tanh', 'recurrent_activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'recurrent_initializer': {'module': 'keras.initializers', 'class_name': 'Orthogonal', 'config': {'gain': 1.0, 'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'unit_forget_bias': True, 'kernel_regularizer': None, 'recurrent_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'recurrent_constraint': None, 'bias_constraint': None, 'dropout': 0.0, 'recurrent_dropout': 0.0, 'implementation': 2}
# Layer output shape: [(None, None, 512), (None, 512), (None, 512)]
#
# Layer index: 6
# Layer name: dense
# Layer type: Dense
# Layer config: {'name': 'dense', 'trainable': True, 'dtype': 'float32', 'units': 91, 'activation': 'softmax', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# Layer output shape: (None, None, 91)

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors
    states_value = encoder_model.predict(input_seq, verbose=0)

    # Generate empty target sequence of length 1
    target_seq = np.zeros((1, 1, num_decoder_tokens))

    # Populate the first character of target sequence with the start character
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    # Sampling loop for a batch of sequences (assume a batch of size 1)
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value, verbose=0
        )

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length or find stop character
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1)
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = [h, c]

    return decoded_sentence

for seq_index in range(20):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index:seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)

    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
    print()
# Out:
# Input sentence: Go.
# Decoded sentence: Partez.
#
#
# Input sentence: Go.
# Decoded sentence: Partez.
#
#
# Input sentence: Go.
# Decoded sentence: Partez.
#
#
# Input sentence: Go.
# Decoded sentence: Partez.
#
#
# Input sentence: Hi.
# Decoded sentence: Salut !
#
#
# Input sentence: Hi.
# Decoded sentence: Salut !
#
#
# Input sentence: Run!
# Decoded sentence: Filez !
#
#
# Input sentence: Run!
# Decoded sentence: Filez !
#
#
# Input sentence: Run!
# Decoded sentence: Filez !
#
#
# Input sentence: Run!
# Decoded sentence: Filez !
#
#
# Input sentence: Run!
# Decoded sentence: Filez !
#
#
# Input sentence: Run!
# Decoded sentence: Filez !
#
#
# Input sentence: Run!
# Decoded sentence: Filez !
#
#
# Input sentence: Run!
# Decoded sentence: Filez !
#
#
# Input sentence: Run.
# Decoded sentence: Filez !
#
#
# Input sentence: Run.
# Decoded sentence: Filez !
#
#
# Input sentence: Run.
# Decoded sentence: Filez !
#
#
# Input sentence: Run.
# Decoded sentence: Filez !
#
#
# Input sentence: Run.
# Decoded sentence: Filez !
#
#
# Input sentence: Run.
# Decoded sentence: Filez !

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

# Calculate BLEU score
def bleu_score(TEST_SIZE):
    smoothie = SmoothingFunction().method4
    bleu_scores = []
    unused_chars = ['\t', '\n', ' ', '\u202f']

    for seq_index in range(TEST_SIZE):
        input_seq = encoder_input_data[seq_index:seq_index + 1]
        decoded_sentence = decode_sequence(input_seq)
        reference = list(filter(lambda x:x not in unused_chars, target_texts[seq_index][1:-1]))
        candidate = list(filter(lambda x:x not in unused_chars, decoded_sentence[:-1]))
        score = sentence_bleu(reference, candidate, smoothing_function=smoothie, weights=(1, 0, 0, 0))
        bleu_scores.append(score)

    return np.mean(bleu_scores)

# Evaluate BLEU score on 100/1000 - 1%/10% of the corpus
print("Average BLEU score on 100 samples:", bleu_score(100))
print("Average BLEU score on 1000 samples:", bleu_score(1000))
# Out:
# Average BLEU score on 100 samples: 0.5513740981240981
# Average BLEU score on 1000 samples: 0.5836922023603642
